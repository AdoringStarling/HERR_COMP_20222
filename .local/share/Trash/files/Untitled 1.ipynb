# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('array.txt',delimiter=';',header=None)

# %%
df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000  0.002000  0.004000  0.006000  0.008000  0.010000  0.012000
# 1    0.000000  0.002000  0.004000  0.006000  0.008000  0.010000  0.012000
# 2    0.000500  0.002000  0.004000  0.006000  0.008000  0.010000  0.012000
# 3    0.000500  0.002000  0.004000  0.006000  0.008000  0.010000  0.012000
# 4    0.000500  0.002000  0.004000  0.006000  0.008000  0.010000  0.012000
# ..        ...       ...       ...       ...       ...       ...       ...
# 494  0.000425  0.001521  0.002964  0.004324  0.005158  0.006065  0.006285
# 495  0.000380  0.001323  0.002783  0.003901  0.004560  0.005271  0.005404
# 496  0.000331  0.001159  0.002517  0.003363  0.003975  0.004332  0.004403
# 497  0.000290  0.001045  0.002123  0.002767  0.003326  0.003322  0.003249
# 498  0.000261  0.000939  0.001620  0.002149  0.002537  0.002295  0.001975
#
#           7         8         9    ...       91        92        93   \
# 0    0.014000  0.016000  0.018000  ...  0.018000  0.016000  0.014000
# 1    0.014000  0.016000  0.018000  ...  0.018000  0.016000  0.014000
# 2    0.014000  0.016000  0.018000  ...  0.018000  0.016000  0.014000
# 3    0.014000  0.016000  0.018000  ...  0.018000  0.016000  0.014000
# 4    0.014000  0.016000  0.018000  ...  0.018000  0.016000  0.014000
# ..        ...       ...       ...  ...       ...       ...       ...
# 494  0.006265  0.005951  0.005504  ...  0.005504  0.005951  0.006265
# 495  0.005061  0.004730  0.004263  ...  0.004263  0.004730  0.005061
# 496  0.003859  0.003474  0.002969  ...  0.002969  0.003474  0.003859
# 497  0.002697  0.002188  0.001664  ...  0.001664  0.002188  0.002697
# 498  0.001546  0.000899  0.000420  ...  0.000420  0.000899  0.001546
#
#           94        95        96        97        98        99   100
# 0    0.012000  0.010000  0.008000  0.006000  0.004000  0.002000  NaN
# 1    0.012000  0.010000  0.008000  0.006000  0.004000  0.002000  NaN
# 2    0.012000  0.010000  0.008000  0.006000  0.004000  0.002000  NaN
# 3    0.012000  0.010000  0.008000  0.006000  0.004000  0.002000  NaN
# 4    0.012000  0.010000  0.008000  0.006000  0.004000  0.002000  NaN
# ..        ...       ...       ...       ...       ...       ...  ...
# 494  0.006285  0.006065  0.005158  0.004324  0.002964  0.001521  NaN
# 495  0.005404  0.005271  0.004560  0.003901  0.002783  0.001323  NaN
# 496  0.004403  0.004332  0.003975  0.003363  0.002517  0.001159  NaN
# 497  0.003249  0.003322  0.003326  0.002767  0.002123  0.001045  NaN
# 498  0.001975  0.002295  0.002537  0.002149  0.001620  0.000939  NaN
#
# [499 rows x 101 columns]

# %%
for i in range(0,500,50):
    print(i)
    size=np.size(df.iloc[:,i])
    plt.plot(np.linspace(0,2,size),df.iloc[:,i],label='t_'+str(i))
plt.legend()
# Out:
# 0
# 50
# 100
# 150
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_317/81910254.py in <module>
#       1 for i in range(0,500,50):
#       2     print(i)
# ----> 3     size=np.size(df.iloc[:,i])
#       4     plt.plot(np.linspace(0,2,size),df.iloc[:,i],label='t_'+str(i))
#       5 plt.legend()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1407             return
#    1408         elif is_integer(key):
# -> 1409             self._validate_integer(key, axis)
#    1410         elif isinstance(key, tuple):
#    1411             # a tuple should already have been caught by this point
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds
